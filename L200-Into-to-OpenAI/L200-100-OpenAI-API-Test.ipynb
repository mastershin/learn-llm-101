# %%
# https://platform.openai.com/docs/api-reference

from google.colab import userdata
openai_key = userdata.get('OPENAI_KEY')

try:
    import openai
except:
    # %pip install -q openai

# %%
# Import the OpenAI class from the openai module
from openai import OpenAI

# Create an instance of the OpenAI class with the provided API key
client = OpenAI(api_key=openai_key)

# Set the user input to the string "Hi"
user_input = "Hi, describe about you in detail and all capabilities in bullet list."

# Create a chat completion using the OpenAI client and the user input
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[{"role": "user", "content": user_input}]
)

# Print the response from the chat completion
print(response.choices[0].message.content)
# Out:
# - I am a motivated and dedicated individual with a strong work ethic
# - I have excellent communication skills and enjoy working in a team environment
# - I am detail-oriented and have a keen eye for accuracy and precision
# - I am highly organized and able to prioritize and manage multiple tasks effectively
# - I have a strong background in (mention specific field or industry)
# - I am proficient in (list relevant software programs or tools)
# - I am a quick learner and adaptable to new environments
# - I am proactive and always seeking new challenges to expand my skills and knowledge.
